# %%
import matplotlib.pyplot as plt
import sys
import warnings

sys.path.insert(0, './codes/hyperspectral_image_processing/denoise')
sys.path.insert(0, './codes/hyperspectral_image_processing/simulation')
sys.path.insert(0, './codes/hyperspectral_image_processing/fusion')
sys.path.insert(0, './codes/hyperspectral_image_processing/quality_metrics')
warnings.filterwarnings('ignore')

from BGLRF_main import BGLRF_main
from Generation import generation
from denoising import denoising
from quality_assessment import quality_assessment

# %%
SRI, hsi,msi = generation()
# Out:
# 0th band
# 1th band
# 2th band
# 3th band
# 4th band
# 5th band
# 6th band
# 7th band
# 8th band
# 9th band
# 10th band
# 11th band
# 12th band
# 13th band
# 14th band
# 15th band
# 16th band
# 17th band
# 18th band
# 19th band
# 20th band
# 21th band
# 22th band
# 23th band
# 24th band
# 25th band
# 26th band
# 27th band
# 28th band
# 29th band
# 30th band
# 31th band
# 32th band
# 33th band
# 34th band
# 35th band
# 36th band
# 37th band
# 38th band
# 39th band
# 40th band
# 41th band
# 42th band
# 43th band
# 44th band
# 45th band
# 46th band
# 47th band
# 48th band
# 49th band
# 50th band
# 51th band
# 52th band
# 53th band
# 54th band
# 55th band
# 56th band
# 57th band
# 58th band
# 59th band
# 60th band
# 61th band
# 62th band
# 63th band
# 64th band
# 65th band
# 66th band
# 67th band
# 68th band
# 69th band
# 70th band
# 71th band
# 72th band
# 73th band
# 74th band
# 75th band
# 76th band
# 77th band
# 78th band
# 79th band
# 80th band
# 81th band
# 82th band
# 83th band
# 84th band
# 85th band
# 86th band
# 87th band
# 88th band
# 89th band
# 90th band
# 91th band
# 92th band
# 93th band
# 94th band
# 95th band
# 96th band
# 97th band
# 98th band
# 99th band
# 100th band
# 101th band
# 102th band
# 103th band
# 104th band
# 105th band
# 106th band
# 107th band
# 108th band
# 109th band
# 110th band
# 111th band
# 112th band
# 113th band
# 114th band
# 115th band
# 116th band
# 117th band
# 118th band
# 119th band
# 120th band
# 121th band
# 122th band
# 123th band
# 124th band
# 125th band
# 126th band
# 127th band
# 128th band
# 129th band
# 130th band
# 131th band
# 132th band
# 133th band
# 134th band
# 135th band
# 136th band
# 137th band
# 138th band
# 139th band
# 140th band
# 141th band
# 142th band
# 143th band
# 144th band
# 145th band
# 146th band
# 147th band
# 148th band
# 149th band
# 150th band
# 151th band
# 152th band
# 153th band
# 154th band
# 155th band
# 156th band
# 157th band
# 158th band
# 159th band
# 160th band
# 161th band
# 162th band
# 163th band
# 164th band
# 165th band
# 166th band
# 167th band
# 168th band
# 169th band
# 170th band
# 171th band
# 172th band
# 173th band
# 174th band
# 175th band
# 176th band
# 177th band
# 178th band
# 179th band
# 180th band
# 181th band
# 182th band
# 183th band
# 184th band
# 185th band
# 186th band
# 187th band
# 188th band
# 189th band
# 190th band
# 191th band
# 192th band
# 193th band
# 194th band
# 195th band
# 196th band
# 197th band
# 198th band
# 199th band

# %%
denoised_hsi,SNR_dB = denoising(hsi)
SRI_fused,K_est = BGLRF_main(denoised_hsi,msi,10,10,6)
# Out:
# 0th band
# 1th band
# 2th band
# 3th band
# 4th band
# 5th band
# 6th band
# 7th band
# 8th band
# 9th band
# 10th band
# 11th band
# 12th band
# 13th band
# 14th band
# 15th band
# 16th band
# 17th band
# 18th band
# 19th band
# 20th band
# 21th band
# 22th band
# 23th band
# 24th band
# 25th band
# 26th band
# 27th band
# 28th band
# 29th band
# 30th band
# 31th band
# 32th band
# 33th band
# 34th band
# 35th band
# 36th band
# 37th band
# 38th band
# 39th band
# 40th band
# 41th band
# 42th band
# 43th band
# 44th band
# 45th band
# 46th band
# 47th band
# 48th band
# 49th band
# 50th band
# 51th band
# 52th band
# 53th band
# 54th band
# 55th band
# 56th band
# 57th band
# 58th band
# 59th band
# 60th band
# 61th band
# 62th band
# 63th band
# 64th band
# 65th band
# 66th band
# 67th band
# 68th band
# 69th band
# 70th band
# 71th band
# 72th band
# 73th band
# 74th band
# 75th band
# 76th band
# 77th band
# 78th band
# 79th band
# 80th band
# 81th band
# 82th band
# 83th band
# 84th band
# 85th band
# 86th band
# 87th band
# 88th band
# 89th band
# 90th band
# 91th band
# 92th band
# 93th band
# 94th band
# 95th band
# 96th band
# 97th band
# 98th band
# 99th band
# 100th band
# 101th band
# 102th band
# 103th band
# 104th band
# 105th band
# 106th band
# 107th band
# 108th band
# 109th band
# 110th band
# 111th band
# 112th band
# 113th band
# 114th band
# 115th band
# 116th band
# 117th band
# 118th band
# 119th band
# 120th band
# 121th band
# 122th band
# 123th band
# 124th band
# 125th band
# 126th band
# 127th band
# 128th band
# 129th band
# 130th band
# 131th band
# 132th band
# 133th band
# 134th band
# 135th band
# 136th band
# 137th band
# 138th band
# 139th band
# 140th band
# 141th band
# 142th band
# 143th band
# 144th band
# 145th band
# 146th band
# 147th band
# 148th band
# 149th band
# 150th band
# 151th band
# 152th band
# 153th band
# 154th band
# 155th band
# 156th band
# 157th band
# 158th band
# 159th band
# 160th band
# 161th band
# 162th band
# 163th band
# 164th band
# 165th band
# 166th band
# 167th band
# 168th band
# 169th band
# 170th band
# 171th band
# 172th band
# 173th band
# 174th band
# 175th band
# 176th band
# 177th band
# 178th band
# 179th band
# 180th band
# 181th band
# 182th band
# 183th band
# 184th band
# 185th band
# 186th band
# 187th band
# 188th band
# 189th band
# 190th band
# 191th band
# 192th band
# 193th band
# 194th band
# 195th band
# 196th band
# 197th band
# 198th band
# 199th band
#   (0, 0)	0.14916147608890573
#   (0, 1)	-0.12238819833757177
#   (0, 2)	0.007734849499889895
#   (0, 144)	0.04208464898250649
#   (0, 145)	0.008905456909865044
#   (0, 146)	-0.12676590162825163
#   (0, 288)	-0.07291765185055202
#   (0, 289)	-0.12830401084487977
#   (0, 290)	0.24248933118008809
#   (1, 0)	-0.12238819833758824
#   (1, 1)	0.3035965835370076
#   (1, 2)	-0.09739264748226557
#   (1, 3)	-0.11770535217545675
#   (1, 144)	0.001797572533360128
#   (1, 145)	-0.3418009292254863
#   (1, 146)	0.1091771883976776
#   (1, 147)	0.23466412432976938
#   (1, 288)	0.04033963461291193
#   (1, 289)	0.21399329494656327
#   (1, 290)	-0.17557923734434697
#   (1, 291)	-0.04870203379214645
#   (2, 0)	0.0077348494998794835
#   (2, 1)	-0.09739264748228167
#   (2, 2)	0.23420505180210238
#   (2, 3)	0.0366574818962241
#   :	:
#   (20733, 20732)	0.049973552624928655
#   (20733, 20733)	0.48592227040122715
#   (20733, 20734)	-0.386294745152894
#   (20733, 20735)	0.1709568900190773
#   (20734, 20444)	-0.27267462464088305
#   (20734, 20445)	0.10408364319590202
#   (20734, 20446)	0.12930608950156425
#   (20734, 20447)	0.09892297563155864
#   (20734, 20588)	-0.014957094332009214
#   (20734, 20589)	0.12130961849136238
#   (20734, 20590)	-0.1297172439651394
#   (20734, 20591)	0.11005581051080084
#   (20734, 20732)	0.03291116141503281
#   (20734, 20733)	-0.3862947451528941
#   (20734, 20734)	0.4074790087201805
#   (20734, 20735)	-0.2004245993754754
#   (20735, 20445)	0.02716559638115585
#   (20735, 20446)	0.1029501108507765
#   (20735, 20447)	-0.11615098413986977
#   (20735, 20589)	-0.02702087227167454
#   (20735, 20590)	-0.18610677143012694
#   (20735, 20591)	-0.33982317384826133
#   (20735, 20733)	0.17095689001907777
#   (20735, 20734)	-0.20042459937547502
#   (20735, 20735)	0.5684538038143976
# (20736, 20736)
# [1.]
# [0.11689935]
# [0.22234875]
# [0.08419581]
# [0.05261536]
# [0.04437988]
# [0.04422047]
# [0.03588529]
# [0.03375394]
# [0.02986715]
# [0.0309679]
# [0.02799461]
# [0.02628327]
# [0.02365203]
# [0.02308972]
# [0.0220257]
# [0.02223258]
# [0.02109006]
# [0.02056983]
# [0.01932069]
# [0.01828821]
# [0.01739819]
# [0.01639829]
# [0.01562675]
# [0.01412289]
# [0.01353164]
# [0.01336054]
# [0.01276656]
# [0.01263489]
# [0.01187186]
# [0.01186418]
# [0.01112496]
# [0.01118212]
# [0.01040769]
# [0.01051457]
# [0.00910289]
# [0.00877488]
# [0.00827881]
# [0.00803743]
# [0.00787919]
# [0.00742955]
# [0.00749989]
# [0.00690922]
# [0.00709913]
# [0.00649908]
# [0.00673432]
# [0.00517749]
# [0.00520981]
# [0.00454663]
# [0.00495336]
# [0.00399945]
# [0.00435492]
# [0.00344602]
# [0.00384091]
# [0.00307954]
# [0.00330964]
# [2.13797087e-05]
# ADMM_K is successful in 56 iterations
#
# CG_X is successful in 293 iterations
#
# GLRF - iteration 0:
#
# 0.0504085524429518
# [0.1649645]
# [0.1988961]
# [0.07617838]
# [0.04244421]
# [0.04981799]
# [0.03729409]
# [0.03662048]
# [0.03233003]
# [0.02949816]
# [0.02810743]
# [0.02460534]
# [0.0250303]
# [0.02163525]
# [0.0224594]
# [0.01821567]
# [0.01946325]
# [0.01544866]
# [0.01657923]
# [0.01281056]
# [0.01465487]
# [0.01118893]
# [0.01226933]
# [0.00943696]
# [0.01023923]
# [0.00817804]
# [0.00924544]
# [0.00785486]
# [2.5874936e-05]
# ADMM_K is successful in 27 iterations
#
# CG_X is successful in 301 iterations
#
# GLRF - iteration 1:
#
# 0.02231718940325249
# [0.12571709]
# [0.22135997]
# [0.06532521]
# [0.03482146]
# [0.03792405]
# [0.02773706]
# [0.02720454]
# [0.02301799]
# [0.01998939]
# [0.01838811]
# [0.01480902]
# [0.01577873]
# [0.01260612]
# [0.01353878]
# [0.01097476]
# [0.01126803]
# [0.00845497]
# [0.00841829]
# [0.00700192]
# [0.00717069]
# [0.00634403]
# [0.00652589]
# [0.00615616]
# [0.00608168]
# [0.00567366]
# [0.00546979]
# [0.00510811]
# [0.00505294]
# [0.00481254]
# [0.00488594]
# [0.00463346]
# [0.00473289]
# [0.00443861]
# [0.00450334]
# [0.00419015]
# [0.00420642]
# [0.00400267]
# [0.00404858]
# [0.00388566]
# [0.00393893]
# [0.00377398]
# [0.00380786]
# [0.00366457]
# [0.00337702]
# [0.00315278]
# [0.00321558]
# [0.00276798]
# [0.00291272]
# [0.00114766]
# [4.0663196e-05]
# ADMM_K is successful in 49 iterations
#
# CG_X is successful in 239 iterations
#
# GLRF - iteration 2:
#
# 0.010609936004507785

# %%
# evaluate the fused result
psnr,rmse,ergas,sam,uiqi,ssim,DD,CCS = quality_assessment(SRI,SRI_fused,0,1/4)

print("psnr", psnr)
print("rmse", psnr)
print("ergas", psnr)
print("sam", psnr)
print("uiqi", psnr)
# Out:
# (144, 144, 200)
# (144, 144, 200)
# (144,)
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# /Users/pronomabanerjee/Dropbox/My Mac (Pronoma’s MacBook Air)/Desktop/UT Austin/HSI-MSI-Image-Fusion/HSI-MSI_Fusion2/Python_Fusion_Demo.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/pronomabanerjee/Dropbox/My%20Mac%20%28Pronoma%E2%80%99s%20MacBook%20Air%29/Desktop/UT%20Austin/HSI-MSI-Image-Fusion/HSI-MSI_Fusion2/Python_Fusion_Demo.ipynb#ch0000003?line=0'>1</a> # evaluate the fused result
# ----> <a href='vscode-notebook-cell:/Users/pronomabanerjee/Dropbox/My%20Mac%20%28Pronoma%E2%80%99s%20MacBook%20Air%29/Desktop/UT%20Austin/HSI-MSI-Image-Fusion/HSI-MSI_Fusion2/Python_Fusion_Demo.ipynb#ch0000003?line=1'>2</a> psnr,rmse,ergas,sam,uiqi,ssim,DD,CCS = quality_assessment(SRI,SRI_fused,0,1/4)
#       <a href='vscode-notebook-cell:/Users/pronomabanerjee/Dropbox/My%20Mac%20%28Pronoma%E2%80%99s%20MacBook%20Air%29/Desktop/UT%20Austin/HSI-MSI-Image-Fusion/HSI-MSI_Fusion2/Python_Fusion_Demo.ipynb#ch0000003?line=3'>4</a> print("psnr", psnr)
#       <a href='vscode-notebook-cell:/Users/pronomabanerjee/Dropbox/My%20Mac%20%28Pronoma%E2%80%99s%20MacBook%20Air%29/Desktop/UT%20Austin/HSI-MSI-Image-Fusion/HSI-MSI_Fusion2/Python_Fusion_Demo.ipynb#ch0000003?line=4'>5</a> print("rmse", psnr)
#
# File ~/Dropbox/My Mac (Pronoma’s MacBook Air)/Desktop/UT Austin/HSI-MSI-Image-Fusion/HSI-MSI_Fusion2/./codes/hyperspectral_image_processing/quality_metrics/quality_assessment.py:70, in quality_assessment(ground_truth, estimated, ignore_edges, ratio_ergas)
#      68 print(aux.shape)
#      69 rmse_per_band = np.sqrt(aux)
# ---> 70 rmse = np.sqrt(np.sum(aux, 2)/n_bands)
#      72 # ERGAS
#      73 mean_y = np.sum(np.sum(y, 0), 1)/n_samples
#
# File <__array_function__ internals>:180, in sum(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2296, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2293         return out
#    2294     return res
# -> 2296 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2297                       initial=initial, where=where)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# AxisError: axis 2 is out of bounds for array of dimension 1

# %%
# print(SRI_fused)
# plt.imshow(SRI_fused[:,:,10].T)
# plt.show()
